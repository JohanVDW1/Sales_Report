# %%
  # ------------------------------------------Method----------------------------------------------------------------
 # Building the board

 # Taking in the Turn

 # Cheking for a win from either X or O

 # Defining what a draw is

 # Looping the process

# ----------------------------------------Building the board-----------------------------------------------------------
Sub_Board = (1 ,2 ,3, 4, 5, 6, 7, 8, 9)
Sub_Board1 = list(Sub_Board)

 # Defining that the game hasnt been won or drawn yet

global Won
Won = False
Draw = False
def Board():
    print(Sub_Board1[0],'|',Sub_Board1[1],'|', Sub_Board1[2])
    print(Sub_Board1[3],'|',Sub_Board1[4],'|', Sub_Board1[5])
    print(Sub_Board1[6],'|',Sub_Board1[7],'|', Sub_Board1[8])


       #Displays the board and gives the positions avilable to take


 # ------------------------------------Taking in the turn----------------------------------------------------------
def TurnX():
    Position = input("Which position do you want to input? ")
    Position = int(Position) - 1
    Sub_Board1[Position] = "X"

   
                



def TurnO():
    Position = input("Which position do you want to input? ")
    Position = int(Position) - 1
    Sub_Board1[Position] = "O"
   

               





 # ---------------------------------------Now cheking for a win from either X or O-------------------------------------


   
def Check_Win():
    
    # Check for horizontal win
   
    Row_Winner1 = Sub_Board1[0] == Sub_Board1[1] == Sub_Board1[2]
    Row_Winner2 = Sub_Board1[3] == Sub_Board1[4] == Sub_Board1[5]
    Row_Winner3 = Sub_Board1[6] == Sub_Board1[7] == Sub_Board1[8]
       
    # Check for Verticle win
   
    Column_Winner1 = Sub_Board1[0] == Sub_Board1[3] == Sub_Board1[6]
    Column_Winner2 = Sub_Board1[1] == Sub_Board1[4] == Sub_Board1[7]
    Column_Winner3 = Sub_Board1[2] == Sub_Board1[5] == Sub_Board1[8]
   
    # Check for diaginal win
   
    Diagonal_Winner1 = Sub_Board1[0] == Sub_Board1[4] == Sub_Board1[8]
    Diagonal_Winner2 = Sub_Board1[2] == Sub_Board1[4] == Sub_Board1[6]
   
    #Searching for if a win has happened
   
    if Row_Winner1 or Row_Winner2 or Row_Winner3 or Column_Winner1 or Column_Winner2 or Column_Winner3 or Diagonal_Winner1 or Diagonal_Winner2:
        global Won
        Won = True
        print("Congratulations we have a winner!!!")


        
 # ----------------------------------------Defining what a draw is---------------------------------------------
def Check_Draw():
    V1 = 0
    V2 = 0
    V3 = 0
    V4 = 0
    V5 = 0
    V6 = 0
    V7 = 0
    V8 = 0
    V9 = 0

    if 1 in Sub_Board1:
        V1 = 1
    if 2 in Sub_Board1:
        V2 = 1
    if 3 in Sub_Board1:
        V3 = 1
    if 4 in Sub_Board1:
        V4 = 1
    if 5 in Sub_Board1:
        V5 = 1
    if 6 in Sub_Board1:
        V6 = 1
    if 7 in Sub_Board1:
        V7 = 1
    if 8 in Sub_Board1:
        V8 = 1
    if 9 in Sub_Board1:
        V9 = 1
    
    if V1 + V2 + V3+ V3 + V4 + V5 + V6 + V7 + V8 + V9 == 0:
        global Draw
        Draw = True
        print("Draw, play again to try to find a winner.")
        
        
    # totaling all values if there are no integers within the game then the game is must either be a win or a draw

    
            
       
       
 # --------------------------------------------Looping the process---------------------------------------------------------
         
       
while Won = False and Draw = False:
    Board()
    TurnO()
    Check_Win()
    if Won = True and Draw = True:
        Board()
        TurnX()
        Check_Win()

Board()
TurnX()
Board()
TurnO()
Board()
TurnX()
Board()
TurnO()
Board()
 # Possiblility of winning after this point
TurnX()
Check_Win()
Board()
TurnO()
Check_Win()
Board()
TurnX()
Check_Win()
Board()
TurnO()
Check_Win()
Board()
TurnX()
Check_Win()
Check_Draw()
Board()   
 # Game must end at this point

    # Check for draw
   
 # --------------------------------------------Displaying the winner-------------------------------------------------------
    
    
 # Things that can be improved
    # Creating a loop for the processes
    # Creating a proper break point
    # If an incorrect value is placed it breaks the game
# Out:
#   Input In [1]
#     while Won = False and Draw = False:
#               ^
# SyntaxError: invalid syntax
